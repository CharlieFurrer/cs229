# %% [markdown]
# #### TSV files are essentially identical to CSV files except that TSV files use "tabs (\t)" while CSV files use commas to store data in tabular structure. As a result, loading TSV files are slightly different from how we've been loading CSV files.
# ##### Thanks to Clara Meister for providing this tutorial.

# %%
# For compatibility across multiple platforms
import os
import numpy as np
import pandas as pd
from scipy import spatial


# Load files using DictReader in Python
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import cluster
from sklearn import preprocessing
from sklearn.model_selection import KFold
import sklearn

# %%
train_filepath = "pubg-finish-placement-prediction/train_V2_clean.csv"

test_filepath = "pubg-finish-placement-prediction/test_V2.csv"

#trainset_file = open(train_filepath,'rU')
trainset = pd.read_csv(train_filepath)

#testset_file = open(test_filepath,'rU')
testset = pd.read_csv(test_filepath)

trainset.dtypes
# Out:
# Unnamed: 0           int64
# Id                   int64
# groupId              int64
# matchId              int64
# assists              int64
# boosts               int64
# damageDealt        float64
# DBNOs                int64
# headshotKills        int64
# heals                int64
# killPlace            int64
# killPoints           int64
# kills                int64
# killStreaks          int64
# longestKill        float64
# matchDuration        int64
# matchType           object
# maxPlace             int64
# numGroups            int64
# rankPoints           int64
# revives              int64
# rideDistance       float64
# roadKills            int64
# swimDistance       float64
# teamKills            int64
# vehicleDestroys      int64
# walkDistance       float64
# weaponsAcquired      int64
# winPoints            int64
# winPlacePerc       float64
# dtype: object

# %% [raw]
# for i in trainset.index:
#     trainset.at[i,"Id"] = int(trainset.at[i,"Id"],16)
#     trainset.at[i,"matchId"] = int(trainset.at[i,"matchId"],16)
#     trainset.at[i,"groupId"] = int(trainset.at[i,"groupId"],16)

# %%
trainset.head()
# Out:
#    Unnamed: 0                 Id            groupId            matchId  \
# 0           0  35913017459246474  21756414768994750  45321147693812369
# 1           1  67264846101073980  29358430787743646  49173965273764108
# 2           2   8637285204745842  29917998133566068   4786602953643182
# 3           3  19728345572649043  47622776820651809  68101503675608446
# 4           4  13894076435569324  62491847359224029  30901772270576102
#
#    assists  boosts  damageDealt  DBNOs  headshotKills  heals      ...       \
# 0        0       0         0.00      0              0      0      ...
# 1        0       0        91.47      0              0      0      ...
# 2        1       0        68.00      0              0      0      ...
# 3        0       0        32.90      0              0      0      ...
# 4        0       0       100.00      0              0      0      ...
#
#    revives  rideDistance  roadKills  swimDistance  teamKills  vehicleDestroys  \
# 0        0        0.0000          0          0.00          0                0
# 1        0        0.0045          0         11.04          0                0
# 2        0        0.0000          0          0.00          0                0
# 3        0        0.0000          0          0.00          0                0
# 4        0        0.0000          0          0.00          0                0
#
#   walkDistance  weaponsAcquired  winPoints  winPlacePerc
# 0       244.80                1       1466        0.4444
# 1      1434.00                5          0        0.6400
# 2       161.80                2          0        0.7755
# 3       202.70                3          0        0.1667
# 4        49.75                2          0        0.1875
#
# [5 rows x 30 columns]

# %% [raw]
# trainset.to_csv("pubg-finish-placement-prediction/valset_V2_clean.csv")

# %% [raw]
# #STEP 2
#
#
# print("len old trainset",len(trainset))
#
# trainset_split = int(.8 * len(trainset))
# valset = trainset[trainset_split:]
# trainset = trainset[:trainset_split]
#
# print("len new trainset",len(trainset))
# print("len valset", len(valset))

# %%
matchTypeIndex = 15
trainset = trainset.drop(["matchType"],axis=1)
train_columns = list(trainset.columns[:-1])


x = trainset[train_columns]
y = trainset["winPlacePerc"]


x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2)

# %%
x_train.head()
# Out:
#                         Id            groupId            matchId  assists  \
# 1292256  63854951985661453    600250450733236  58790947321507903        0
# 130376   30797503102741404  66137564618002392  31638120576856294        0
# 531321   20500043549537120  67703441911112710  63956714187954744        0
# 3553841  53991784096945239  43602287311196324  66532421895858817        0
# 2531761  55471076664019257  52081892748649858  57819140417290411        0
#
#          boosts  damageDealt  DBNOs  headshotKills  heals  killPlace  \
# 1292256       0         0.00      0              0      0         86
# 130376        0       392.30      0              1      0         11
# 531321        1         0.00      0              0      1         68
# 3553841       3        93.14      0              0      1         53
# 2531761       0         0.00      0              0      0         42
#
#            ...      rankPoints  revives  rideDistance  roadKills  \
# 1292256    ...            1527        0           0.0          0
# 130376     ...            1497        0           0.0          0
# 531321     ...              -1        0           0.0          0
# 3553841    ...              -1        0        2966.0          0
# 2531761    ...              -1        0           0.0          0
#
#          swimDistance  teamKills  vehicleDestroys  walkDistance  \
# 1292256           0.0          0                0         161.9
# 130376            0.0          0                0         111.6
# 531321            0.0          0                0         573.0
# 3553841           0.0          0                0        2435.0
# 2531761           0.0          0                0         331.2
#
#          weaponsAcquired  winPoints
# 1292256                3          0
# 130376                 2          0
# 531321                 4       1497
# 3553841                3       1536
# 2531761                2       1464
#
# [5 rows x 27 columns]

# %%
def includeFeatures(trainset,featuresToInclude):
    featuresToInclude = set(featuresToInclude)
    for feature in trainset.columns:
        if feature not in featuresToInclude:
            trainset.drop(feature,axis=1)

# %%
print(trainset.columns)
# Out:
# Index([u'Id', u'groupId', u'matchId', u'assists', u'boosts', u'damageDealt',
#        u'DBNOs', u'headshotKills', u'heals', u'killPlace', u'killPoints',
#        u'kills', u'killStreaks', u'longestKill', u'matchDuration', u'maxPlace',
#        u'numGroups', u'rankPoints', u'revives', u'rideDistance', u'roadKills',
#        u'swimDistance', u'teamKills', u'vehicleDestroys', u'walkDistance',
#        u'weaponsAcquired', u'winPoints', u'winPlacePerc'],
#       dtype='object')

# %% [raw]
# featuresToRemove =["Id","groupId","matchId","matchType"]
# #featuresToInclude = ["assists","damageDealt","headshotKills","killPoints","maxPlace","rankPoints","walkDistance","rideDistance","matchDuration","winPoints","revives","winPlacePerc"]
#
#
# trainset = trainset.drop(featuresToRemove,axis=1)
# valset = valset.drop(featuresToRemove,axis=1)
#
# includeFeatures(trainset,featuresToInclude)
# includeFeatures(valset,featuresToInclude)

# %% [raw]
# x_train,y_train = trainset.iloc[:,:-1],trainset.iloc[:,-1]
# x_val,y_val = valset.iloc[:,:-1],valset.iloc[:,-1]
#
#
# print(x_train)
# print(y_train)
# print(x_val)
# print(y_val)

# %%
trainset_dmatrix = xgb.DMatrix(x_train.values,label=y_train.values)
valset_dmatrix = xgb.DMatrix(x_val.values,label=y_val.values)

# %%
params = {
    "max_depth" : 5,
    "eval_metric" : ["mae"],
}

# %%
clf = xgb.train(params, trainset_dmatrix, evals=[(trainset_dmatrix, "train"),(valset_dmatrix, 'val')], num_boost_round = 50)

predictions = xgb.predict(valset_dmatrix)
# Out:
# [18:49:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [0]	train-mae:0.201157	val-mae:nan
# [18:49:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [1]	train-mae:0.156014	val-mae:nan
# [18:49:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [2]	train-mae:0.126411	val-mae:nan
# [18:49:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [3]	train-mae:0.106182	val-mae:nan
# [18:49:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [4]	train-mae:0.092854	val-mae:nan
# [18:50:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [5]	train-mae:0.085187	val-mae:nan
# [18:50:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [6]	train-mae:0.079649	val-mae:nan
# [18:50:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [7]	train-mae:0.076236	val-mae:nan
# [18:50:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [8]	train-mae:0.073273	val-mae:nan
# [18:50:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [9]	train-mae:0.07176	val-mae:nan
# [18:50:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [10]	train-mae:0.070349	val-mae:nan
# [18:51:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [11]	train-mae:0.069306	val-mae:nan
# [18:51:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [12]	train-mae:0.068744	val-mae:nan
# [18:51:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [13]	train-mae:0.067946	val-mae:nan
# [18:51:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [14]	train-mae:0.067576	val-mae:nan
# [18:51:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [15]	train-mae:0.067018	val-mae:nan
# [18:51:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [16]	train-mae:0.066793	val-mae:nan
# [18:52:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [17]	train-mae:0.066222	val-mae:nan
# [18:52:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [18]	train-mae:0.065988	val-mae:nan
# [18:52:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [19]	train-mae:0.065673	val-mae:nan
# [18:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [20]	train-mae:0.065128	val-mae:nan
# [18:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [21]	train-mae:0.064792	val-mae:nan
# [18:52:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [22]	train-mae:0.064675	val-mae:nan
# [18:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [23]	train-mae:0.064335	val-mae:nan
# [18:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [24]	train-mae:0.063983	val-mae:nan
# [18:53:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [25]	train-mae:0.063907	val-mae:nan
# [18:53:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [26]	train-mae:0.063841	val-mae:nan
# [18:53:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [27]	train-mae:0.063733	val-mae:nan
# [18:53:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [28]	train-mae:0.063426	val-mae:nan
# [18:54:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [29]	train-mae:0.06337	val-mae:nan
# [18:54:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [30]	train-mae:0.063219	val-mae:nan
# [18:54:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [31]	train-mae:0.06317	val-mae:nan
# [18:54:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [32]	train-mae:0.063078	val-mae:nan
# [18:54:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [33]	train-mae:0.062901	val-mae:nan
# [18:54:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [34]	train-mae:0.062612	val-mae:nan
# [18:55:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [35]	train-mae:0.062489	val-mae:nan
# [18:55:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [36]	train-mae:0.062417	val-mae:nan
# [18:55:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [37]	train-mae:0.062382	val-mae:nan
# [18:55:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [38]	train-mae:0.062195	val-mae:nan
# [18:55:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [39]	train-mae:0.062013	val-mae:nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /anaconda2/lib/python2.7/site-packages/xgboost/core.pyc in _log_callback(msg)
#     101
#     102
# --> 103 def _log_callback(msg):
#     104     """Redirect logs from native library into Python console"""
#     105     print("{0:s}".format(py_str(msg)))
#
# KeyboardInterrupt:
# [40]	train-mae:0.061916	val-mae:nan
# [18:56:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [41]	train-mae:0.061776	val-mae:nan
# [18:56:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [42]	train-mae:0.061705	val-mae:nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /anaconda2/lib/python2.7/site-packages/xgboost/core.pyc in _log_callback(msg)
#     101
#     102
# --> 103 def _log_callback(msg):
#     104     """Redirect logs from native library into Python console"""
#     105     print("{0:s}".format(py_str(msg)))
#
# KeyboardInterrupt:
# [43]	train-mae:0.061652	val-mae:nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /anaconda2/lib/python2.7/site-packages/xgboost/core.pyc in _log_callback(msg)
#     101
#     102
# --> 103 def _log_callback(msg):
#     104     """Redirect logs from native library into Python console"""
#     105     print("{0:s}".format(py_str(msg)))
#
# KeyboardInterrupt:
# [44]	train-mae:0.06163	val-mae:nan
# [18:56:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [45]	train-mae:0.061516	val-mae:nan
# [18:56:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [46]	train-mae:0.061459	val-mae:nan
# [18:57:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [47]	train-mae:0.061409	val-mae:nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# /anaconda2/lib/python2.7/site-packages/xgboost/core.pyc in _log_callback(msg)
#     101
#     102
# --> 103 def _log_callback(msg):
#     104     """Redirect logs from native library into Python console"""
#     105     print("{0:s}".format(py_str(msg)))
#
# KeyboardInterrupt:
# [48]	train-mae:0.06132	val-mae:nan
# [18:57:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [49]	train-mae:0.061281	val-mae:nan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-172-1af3680a7a6f> in <module>()
#       2 clf = xgb.train(params, trainset_dmatrix, evals=[(trainset_dmatrix, "train"),(valset_dmatrix, 'val')], num_boost_round = 50)
#       3
# ----> 4 predictions = xgb.predict(valset_dmatrix)
#
# AttributeError: 'module' object has no attribute 'predict'
