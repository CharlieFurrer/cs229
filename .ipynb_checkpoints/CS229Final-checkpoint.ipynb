# %% [markdown]
# #### TSV files are essentially identical to CSV files except that TSV files use "tabs (\t)" while CSV files use commas to store data in tabular structure. As a result, loading TSV files are slightly different from how we've been loading CSV files.
# ##### Thanks to Clara Meister for providing this tutorial.

# %%
# For compatibility across multiple platforms
import os
import numpy as np
import pandas as pd
from scipy import spatial


# Load files using DictReader in Python
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import cluster
from sklearn import preprocessing
from sklearn.model_selection import KFold
import sklearn

# %%
train_filepath = "pubg-finish-placement-prediction/train_V2.csv"

test_filepath = "pubg-finish-placement-prediction/test_V2.csv"

#trainset_file = open(train_filepath,'rU')
trainset = pd.read_csv(train_filepath)

#testset_file = open(test_filepath,'rU')
testset = pd.read_csv(test_filepath)

trainset.dtypes
# Out:
# Id                  object
# groupId             object
# matchId             object
# assists              int64
# boosts               int64
# damageDealt        float64
# DBNOs                int64
# headshotKills        int64
# heals                int64
# killPlace            int64
# killPoints           int64
# kills                int64
# killStreaks          int64
# longestKill        float64
# matchDuration        int64
# matchType           object
# maxPlace             int64
# numGroups            int64
# rankPoints           int64
# revives              int64
# rideDistance       float64
# roadKills            int64
# swimDistance       float64
# teamKills            int64
# vehicleDestroys      int64
# walkDistance       float64
# weaponsAcquired      int64
# winPoints            int64
# winPlacePerc       float64
# dtype: object

# %%
for row in trainset.iterrows():
    row["Id"] = int(row["Id"],16)
    row["matchId"] = int(row["matchId"],16)
    row["groupId"] = int(row["groupId"],16)



trainset["Id"] = pd.to_numeric(trainset["Id"], errors='coerce').fillna(0).astype(np.int64)
trainset["matchId"] = pd.to_numeric(trainset["matchId"], errors='coerce').fillna(0).astype(np.int64)
trainset["groupId"] = pd.to_numeric(trainset["groupId"], errors='coerce').fillna(0).astype(np.int64)
trainset.head()
# Out:
#    Id  groupId  matchId  assists  boosts  damageDealt  DBNOs  headshotKills  \
# 0   0        0        0        0       0         0.00      0              0
# 1   0        0        0        0       0        91.47      0              0
# 2   0        0        0        1       0        68.00      0              0
# 3   0        0        0        0       0        32.90      0              0
# 4   0        0        0        0       0       100.00      0              0
#
#    heals  killPlace      ...       revives  rideDistance  roadKills  \
# 0      0         60      ...             0        0.0000          0
# 1      0         57      ...             0        0.0045          0
# 2      0         47      ...             0        0.0000          0
# 3      0         75      ...             0        0.0000          0
# 4      0         45      ...             0        0.0000          0
#
#    swimDistance  teamKills vehicleDestroys  walkDistance  weaponsAcquired  \
# 0          0.00          0               0        244.80                1
# 1         11.04          0               0       1434.00                5
# 2          0.00          0               0        161.80                2
# 3          0.00          0               0        202.70                3
# 4          0.00          0               0         49.75                2
#
#    winPoints  winPlacePerc
# 0       1466        0.4444
# 1          0        0.6400
# 2          0        0.7755
# 3          0        0.1667
# 4          0        0.1875
#
# [5 rows x 29 columns]

# %% [raw]
# #STEP 2
#
#
# print("len old trainset",len(trainset))
#
# trainset_split = int(.8 * len(trainset))
# valset = trainset[trainset_split:]
# trainset = trainset[:trainset_split]
#
# print("len new trainset",len(trainset))
# print("len valset", len(valset))

# %%
matchTypeIndex = 15
trainset = trainset.drop(["matchType"],axis=1)
train_columns = list(trainset.columns[:-1])


x = trainset[train_columns]
y = trainset["winPlacePerc"]

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2)

# %%
def includeFeatures(trainset,featuresToInclude):
    featuresToInclude = set(featuresToInclude)
    for feature in trainset.columns:
        if feature not in featuresToInclude:
            trainset.drop(feature,axis=1)

# %%
print(trainset.columns)
# Out:
# Index([u'assists', u'boosts', u'damageDealt', u'DBNOs', u'headshotKills',
#        u'heals', u'killPlace', u'killPoints', u'kills', u'killStreaks',
#        u'longestKill', u'matchDuration', u'maxPlace', u'numGroups',
#        u'rankPoints', u'revives', u'rideDistance', u'roadKills',
#        u'swimDistance', u'teamKills', u'vehicleDestroys', u'walkDistance',
#        u'weaponsAcquired', u'winPoints', u'winPlacePerc'],
#       dtype='object')

# %% [raw]
# featuresToRemove =["Id","groupId","matchId","matchType"]
# featuresToInclude = ["assists","damageDealt","headshotKills","killPoints","maxPlace","rankPoints","walkDistance","rideDistance","matchDuration","winPoints","revives","winPlacePerc"]
#
#
# trainset = trainset.drop(featuresToRemove,axis=1)
# valset = valset.drop(featuresToRemove,axis=1)
#
# includeFeatures(trainset,featuresToInclude)
# includeFeatures(valset,featuresToInclude)

# %% [raw]
# x_train,y_train = trainset.iloc[:,:-1],trainset.iloc[:,-1]
# x_val,y_val = valset.iloc[:,:-1],valset.iloc[:,-1]
#
#
# print(x_train)
# print(y_train)
# print(x_val)
# print(y_val)

# %%
trainset_dmatrix = xgb.DMatrix(x_train.values,label=y_train.values)
valset_dmatrix = xgb.DMatrix(x_val.values,label=y_val.values)

# %%
params = {
    "max_depth" : 5,
    "eval_metric" : ["mae"],
}

# %%
clf = xgb.train(params, trainset_dmatrix, evals=[(trainset_dmatrix, "train"),(valset_dmatrix, 'val')], num_boost_round = 50)

predictions = xgb.predict(valset_dmatrix)
# Out:
# [17:57:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [0]	train-mae:nan	val-mae:0.269341
# [17:57:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [1]	train-mae:nan	val-mae:0.269341
# [17:58:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [2]	train-mae:nan	val-mae:0.269341
# [17:58:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [3]	train-mae:nan	val-mae:0.269341
# [17:58:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [4]	train-mae:nan	val-mae:0.269341
# [17:58:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [5]	train-mae:nan	val-mae:0.269341
# [17:58:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [6]	train-mae:nan	val-mae:0.269341
# [17:58:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [7]	train-mae:nan	val-mae:0.269341
# [17:58:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [8]	train-mae:nan	val-mae:0.269341
# [17:58:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [9]	train-mae:nan	val-mae:0.269341
# [17:58:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10]	train-mae:nan	val-mae:0.269341
# [17:58:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [11]	train-mae:nan	val-mae:0.269341
# [17:58:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12]	train-mae:nan	val-mae:0.269341
# [17:58:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [13]	train-mae:nan	val-mae:0.269341
# [17:58:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [14]	train-mae:nan	val-mae:0.269341
# [17:58:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15]	train-mae:nan	val-mae:0.269341
# [17:58:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [16]	train-mae:nan	val-mae:0.269341
# [17:58:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [17]	train-mae:nan	val-mae:0.269341
# [17:58:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [18]	train-mae:nan	val-mae:0.269341
# [17:58:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [19]	train-mae:nan	val-mae:0.269341
# [17:58:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [20]	train-mae:nan	val-mae:0.269341
# [17:58:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [21]	train-mae:nan	val-mae:0.269341
# [17:58:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [22]	train-mae:nan	val-mae:0.269341
# [17:59:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23]	train-mae:nan	val-mae:0.269341
# [17:59:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [24]	train-mae:nan	val-mae:0.269341
# [17:59:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [25]	train-mae:nan	val-mae:0.269341
# [17:59:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [26]	train-mae:nan	val-mae:0.269341
# [17:59:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [27]	train-mae:nan	val-mae:0.269341
# [17:59:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [28]	train-mae:nan	val-mae:0.269341
# [17:59:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [29]	train-mae:nan	val-mae:0.269341
# [17:59:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [30]	train-mae:nan	val-mae:0.269341
# [17:59:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [31]	train-mae:nan	val-mae:0.269341
# [17:59:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [32]	train-mae:nan	val-mae:0.269341
# [17:59:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [33]	train-mae:nan	val-mae:0.269341
# [17:59:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [34]	train-mae:nan	val-mae:0.269341
# [17:59:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [35]	train-mae:nan	val-mae:0.269341
# [17:59:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [36]	train-mae:nan	val-mae:0.269341
# [17:59:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [37]	train-mae:nan	val-mae:0.269341
# [17:59:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [38]	train-mae:nan	val-mae:0.269341
# [17:59:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [39]	train-mae:nan	val-mae:0.269341
# [17:59:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [40]	train-mae:nan	val-mae:0.269341
# [17:59:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [41]	train-mae:nan	val-mae:0.269341
# [17:59:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [42]	train-mae:nan	val-mae:0.269341
# [17:59:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [43]	train-mae:nan	val-mae:0.269341
# [18:00:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [44]	train-mae:nan	val-mae:0.269341
# [18:00:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [45]	train-mae:nan	val-mae:0.269341
# [18:00:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [46]	train-mae:nan	val-mae:0.269341
# [18:00:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [47]	train-mae:nan	val-mae:0.269341
# [18:00:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [48]	train-mae:nan	val-mae:0.269341
# [18:00:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [49]	train-mae:nan	val-mae:0.269341
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-1af3680a7a6f> in <module>()
#       2 clf = xgb.train(params, trainset_dmatrix, evals=[(trainset_dmatrix, "train"),(valset_dmatrix, 'val')], num_boost_round = 50)
#       3
# ----> 4 predictions = xgb.predict(valset_dmatrix)
#
# AttributeError: 'module' object has no attribute 'predict'
